# %% [markdown]
# # Error Analysis
#
# Inspect misclassified beats: which classes are confused, and sample waveforms.

# %%
from utils import AAMI_CLASSES
print("Classes:", AAMI_CLASSES)
# Load model and test set; compute predictions; compare y_true vs y_pred
# Focus on confusion pairs (e.g. S vs N, V vs F) and optionally plot example beats.
