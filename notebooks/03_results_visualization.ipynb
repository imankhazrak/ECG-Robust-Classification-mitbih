# %% [markdown]
# # Results Visualization
#
# Load CSVs and figures from results/ for summary tables and robustness/learning curves.

# %%
import pandas as pd
from pathlib import Path
results = Path("..") / "results"
for f in results.glob("*.csv"):
    print(f.name)
    print(pd.read_csv(f).head().to_string())
